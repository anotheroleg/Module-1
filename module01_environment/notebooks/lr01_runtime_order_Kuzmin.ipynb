# %% [markdown]
# **Текстовая карточка** в рамках лабораторной работы

# %%
# Создаем текстовую переменную (карточку):

text_card = """

--- ТЕКСТОВАЯ КАРТОЧКА ---
Имя: Олег
Уровень лабы: Средний
--------------------------
"""

# %%
print(text_card)
# Out:
# --- ТЕКСТОВАЯ КАРТОЧКА ---
# Имя: Олег
# Уровень лабы: Средний
# --------------------------
